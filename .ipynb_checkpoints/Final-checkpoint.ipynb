# %% [markdown]
# #### In this project, we are interested in using k-means algorithm in Image

# %% [markdown]
# k-means algorithm is used here to cluster similar pixilated color position and visualize when we tweek with this clusterd location

# %% [markdown]
# ##### Importing required libraries

# %%
# library for clustering position
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
# library for mathmatics computation
import numpy as np
#library for image processing
import cv2 
import os

# %% [markdown]
# #####  For google colabs only

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-30855732-7231-43e1-b787-da7f63b7b510" name="files[]" multiple disabled />
#      <output id="result-30855732-7231-43e1-b787-da7f63b7b510">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving img.jpg to img (1).jpg

# %%
image1 = cv2.imread('img.jpg')

# %% [markdown]
# ###### Here uploaded image is assigned in variable, as this is done in cloud.

# %%
image2 = image1

# %%
(h1, w1) = image2.shape[:2]

# %%
print(h1, w1)
# Out:
# 1560 1170

# %% [markdown]
# ##### Our uploaded has dimension of 1560px to 1170px

# %%
image1 = image2.reshape((image2.shape[0] * image2.shape[1], 3))

# %%
clt = KMeans(n_clusters = 6)

# %%
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2LAB)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(image2)

# %% [markdown]
# We, can see the result of tweeking 6 kinds of clustered pixel value in our image

# %% [markdown]
# ##### Here, we are looking how different value of K i.e number of cluster has an effect in output image

# %%
plt.figure(figsize=(25,10))
for k in range(70,74):
  clt = KMeans(n_clusters = k)
  quant1 = quant1.reshape((h1, w1, 3))
  image1 = image1.reshape((h1, w1, 3))
  quant1 = cv2.cvtColor(quant1, cv2.COLOR_LAB2BGR)
  image1 = cv2.cvtColor(image1, cv2.COLOR_LAB2BGR)
  plt.subplot(1, 4, k-69)
  plt.imshow(image1)

# %% [markdown]
# #### Outcome:
# ##### As, we can easily visualize the effect of tweeking different number of cluster pixeleted value in our image.
